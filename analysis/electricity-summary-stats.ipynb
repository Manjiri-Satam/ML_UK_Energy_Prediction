# %%
import sqlite3

# %%
connection = sqlite3.connect('../data/ml-power.db')
c = connection.cursor()

# %%
c.execute("SELECT CAST(ELECKWH AS numeric_type) FROM elec LIMIT 100;")
for row in c.fetchall():
    print(row)
# Out:
# (0,)
# (0.6,)
# (0.25,)
# (0.3,)
# (0.4,)
# (0.85,)
# (0.2,)
# (0.5,)
# (0.85,)
# (0.1,)
# (0.15,)
# (0.35,)
# (0.8,)
# (0.1,)
# (0.3,)
# (0.05,)
# (0.75,)
# (0.2,)
# (0.05,)
# (0.25,)
# (0.45,)
# (0.3,)
# (0.95,)
# (0.2,)
# (0.15,)
# (0.05,)
# (0.45,)
# (0.25,)
# (1.6,)
# (0.3,)
# (0.1,)
# (0.11,)
# (0.28,)
# (0.15,)
# (0.16,)
# (0.2,)
# (0.19,)
# (0.14,)
# (0.82,)
# (0.21,)
# (0.8,)
# (0.5,)
# (0.2,)
# (0.3,)
# (0.75,)
# (0.6,)
# (0.1,)
# (0.2,)
# (0.3,)
# (0.1,)
# (0.1,)
# (0.15,)
# (0.2,)
# (0.4,)
# (0.3,)
# (0.3,)
# (0.35,)
# (0.15,)
# (0.2,)
# (0.95,)
# (0.05,)
# (0.25,)
# (0.1,)
# (0.75,)
# (0.2,)
# (0.1,)
# (0.1,)
# (0.95,)
# (0.35,)
# (0.1,)
# (0.15,)
# (0.75,)
# (1.6,)
# (0.3,)
# (0.81,)
# (0.08,)
# (0.18,)
# (0.22,)
# (0.11,)
# (0.29,)
# (0.25,)
# (0.12,)
# (0.51,)
# (0.6,)
# (0.25,)
# (0.1,)
# (0.35,)
# (0.25,)
# (0.75,)
# (0.1,)
# (0.25,)
# (0.45,)
# (0.15,)
# (0.25,)
# (1.25,)
# (0.1,)
# (0.15,)
# (0.15,)
# (0.75,)
# (0.05,)
